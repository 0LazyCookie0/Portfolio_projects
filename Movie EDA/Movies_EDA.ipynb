# %% [markdown]
# # Python Cinema: Analyzing Movies using EDA Techniques

# %% [markdown]
# ## Introduction
# This is a Python **EDA** project focused on analyzing a dataset of movies.\
# The data set used in this project is taken from kaggle and can be found [here](https://www.kaggle.com/datasets/danielgrijalvas/movies).
# ##### *EDA techniques used*
# Throughout this project, we will apply a variety of EDA techniques to gain valuable insights from the movie dataset. These techniques include:
#
# 1. **Summary Statistics**: We will calculate descriptive statistics such as mean, median, standard deviation, and quartiles to understand the central tendencies and distributions of variables.
# 2. **Correlation Analysis**: We will examine correlations between variables, such as ratings and box office performance, to determine if there are any significant relationships worth exploring further.
# 3. **Feature Engineering**: We may extract additional features from the existing dataset or transform existing features to derive new insights. For example, we could create a feature that represents the profit margin by subtracting the budget from the box office revenue.
# 4. **Data Visualization**: Utilizing Matplotlib and Seaborn, we will create visually appealing charts, graphs, and plots to visualize patterns, trends, and relationships within the dataset. These visualizations will aid in identifying popular genres, analyzing box office performance, and exploring relationships between variables.

# %% [markdown]
# ## Importing libaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

plt.style.use('ggplot')

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Reading in the file

# %%
df = pd.read_csv('movies.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Dataset Overview

# %%
# Getting a first look at data
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country      budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000.0
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000.0
# 2              Leigh Brackett       Mark Hamill   United States  18000000.0
# 3                Jim Abrahams       Robert Hays   United States   3500000.0
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000.0
# ...                       ...               ...             ...         ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000.0
# 7664              Lisa Huston  Michael Saquella   United States         NaN
# 7665             Lynno Lovert      Onyama Laura   United States     58750.0
# 7666            James Randall     Christina Roz   United States     15000.0
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         NaN
#
#             gross                    company  runtime
# 0      46998772.0               Warner Bros.    146.0
# 1      58853106.0          Columbia Pictures    104.0
# 2     538375067.0                  Lucasfilm    124.0
# 3      83453539.0         Paramount Pictures     88.0
# 4      39846344.0             Orion Pictures     98.0
# ...           ...                        ...      ...
# 7663          NaN                        NaN     90.0
# 7664          NaN  Cactus Blue Entertainment     90.0
# 7665          NaN           Embi Productions      NaN
# 7666          NaN                        NaN    120.0
# 7667          NaN                PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %%
#Getting a description of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
# Display statistical summary of the dataset
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
# Check for missing values
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
#checking for percentage of missing values
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df
# Out:
#           percent_missing
# name             0.000000
# rating           1.004173
# genre            0.000000
# year             0.000000
# released         0.026082
# score            0.039124
# votes            0.039124
# director         0.000000
# writer           0.039124
# star             0.013041
# country          0.039124
# budget          28.312467
# gross            2.464789
# company          0.221701
# runtime          0.052165

# %%
# Check for duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Data Cleaning and Preprocessing
# - If there are any missing values or inconsistencies in the dataset, we need to clean and preprocess the data before proceeding with the analysis.

# %%
#Dropping the null values
df.dropna(inplace=True)

#Resetting index
df.reset_index(inplace=True)

# %%
#converting columnn types from float to integer
df['votes'] = df['votes'].astype('int64')
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')

# %% [markdown]
# ***Note*** : To make sure there is no dissimilarity between released year and country of release, we will breakdown the released column
#     into 3 different columns named year, country and date and drop the existing ones

# %%
#splitting up the released column to get date and country
df[['released_date', 'correct_country']] = df['released'].str.split('(', expand=True)

#cleaning up the correct_country column
df['correct_country'] = df['correct_country'].str.rstrip(')')

#splitting up the released date colunm into date and year
df[['corect_date', 'correct_year']] = df['released_date'].str.split(',', expand=True)

#changing year type to numeric
df['correct_year'] = pd.to_numeric(df['correct_year'])

#dropping unnecessary column
df.drop(columns=['country', 'released', 'year', 'released_date'], inplace=True)

del df['index']

df.head()
# Out:
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
#
#      votes         director                   writer            star  \
# 0   927000  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    65000   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2  1200000   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3   221000     Jim Abrahams             Jim Abrahams     Robert Hays
# 4   108000     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#      budget      gross             company  runtime correct_country  \
# 0  19000000   46998772        Warner Bros.      146   United States
# 1   4500000   58853106   Columbia Pictures      104   United States
# 2  18000000  538375067           Lucasfilm      124   United States
# 3   3500000   83453539  Paramount Pictures       88   United States
# 4   6000000   39846344      Orion Pictures       98   United States
#
#   corect_date  correct_year
# 0     June 13        1980.0
# 1      July 2        1980.0
# 2     June 20        1980.0
# 3      July 2        1980.0
# 4     July 25        1980.0

# %% [markdown]
# ### Correlation Analysis

# %%
#correlation of numeric values
df.corr()
# Out:
#                  score     votes    budget     gross   runtime  correct_year
# score         1.000000  0.474256  0.072001  0.222556  0.414068      0.061443
# votes         0.474256  1.000000  0.439675  0.614751  0.352303      0.202215
# budget        0.072001  0.439675  1.000000  0.740247  0.318695      0.319669
# gross         0.222556  0.614751  0.740247  1.000000  0.275796      0.268141
# runtime       0.414068  0.352303  0.318695  0.275796  1.000000      0.075183
# correct_year  0.061443  0.202215  0.319669  0.268141  0.075183      1.000000

# %%
#Visualizing correlation of numeric values
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.show()

# %% [markdown]
# ##### *Observation*
# - Budget and gross are highly correlated
# - Votes and gross are also somewhat correlated

# %%
#plotting budget and gross
plt.scatter(x= df['budget'], y= df['gross'], alpha=0.75, edgecolors='black', linewidths=0.5)
plt.title('Budget vs Gross earnings')
plt.xlabel(('Budget of the movie'))
plt.ylabel(('Gross earning of the movie'))
# Out:
# Text(0, 0.5, 'Gross earning of the movie')

# %%
#plot budget vs gross using seaborn
sns.regplot(x= 'budget', y= 'gross', data=df, line_kws= {'color': 'blue', 'linewidth' : '1'}, scatter_kws=
            {'alpha' : 0.75, 'edgecolors' : 'black', 'linewidths' : 0.5})
plt.title('Budget vs Gross earnings')
plt.xlabel(('Budget of the movie'))
plt.ylabel(('Gross earning of the movie'))
# Out:
# Text(0, 0.5, 'Gross earning of the movie')

# %%
#Ploting votes and gross
plt.scatter(x= df['votes'], y= df['gross'], alpha=0.75, edgecolors='black', linewidths=0.5)
plt.title('Votes vs Gross earnings')
plt.xlabel(('Votes of the movie'))
plt.ylabel(('Gross earning of the movie'))
# Out:
# Text(0, 0.5, 'Gross earning of the movie')

# %%
#plot votes vs gross using seaborn
sns.regplot(x= 'votes', y= 'gross', data=df, line_kws= {'color': 'blue',  'linewidth' : '1'}, scatter_kws=
            {'alpha' : 0.75, 'edgecolors' : 'black', 'linewidths' : 0.5})
plt.title('votes vs Gross earnings')
plt.xlabel(('votes of the movie'))
plt.ylabel(('Gross earning of the movie'))
# Out:
# Text(0, 0.5, 'Gross earning of the movie')

# %%
#Plotting votes vs score
plt.scatter(y= df['votes'], x= df['gross'], alpha=0.75, edgecolors='black', linewidths=0.5)
plt.title('Votes vs Gross of the movie')
plt.xlabel(('Votes of the movie'))
plt.ylabel(('Gross of the movie'))
# Out:
# Text(0, 0.5, 'Gross of the movie')

# %%
#plot votes vs gross using seaborn
sns.regplot(y= 'votes', x= 'gross', data=df, line_kws= {'color': 'blue',  'linewidth' : '1'}, scatter_kws=
            {'alpha' : 0.75, 'edgecolors' : 'black', 'linewidths' : 0.5})
plt.title('votes vs Gross of the movie')
plt.xlabel(('Votes of the movie'))
plt.ylabel(('Gross of the movie'))
# Out:
# Text(0, 0.5, 'Gross of the movie')

# %%
#converting all columns to numeric
df_numeric = df.copy()
for col_name in df_numeric.columns:
    if(df_numeric[col_name].dtype == 'object'):
        df_numeric[col_name] =df_numeric[col_name].astype('category')
        df_numeric[col_name] = df_numeric[col_name].cat.codes

df_numeric
# Out:
#       name  rating  genre  score    votes  director  writer  star     budget  \
# 0     4692       6      6    8.4   927000      1795    2832   699   19000000
# 1     3929       6      1    5.8    65000      1578    1158   214    4500000
# 2     3641       4      0    8.7  1200000       757    1818  1157   18000000
# 3      204       4      4    7.7   221000       889    1413  1474    3500000
# 4      732       6      4    7.3   108000       719     351   271    6000000
# ...    ...     ...    ...    ...      ...       ...     ...   ...        ...
# 5416   415       6      0    6.6   140000        16    2390  1812   90000000
# 5417  3556       4      0    6.5   102000       852    2309   147   85000000
# 5418  1153       4      1    5.6    53000      1809    2827  1470  175000000
# 5419  3978       4      1    6.8    42000       294    2091   640  135000000
# 5420  4090       3      0    6.8     3700       746    1184  1839   80000000
#
#           gross  company  runtime  correct_country  corect_date  correct_year
# 0      46998772     1426      146               47          193        1980.0
# 1      58853106      452      104               47          169        1980.0
# 2     538375067      945      124               47          201        1980.0
# 3      83453539     1108       88               47          169        1980.0
# 4      39846344     1083       98               47          175        1980.0
# ...         ...      ...      ...              ...          ...           ...
# 5416  426505244      452      124               47          134        2020.0
# 5417  319715683     1108       99               47          102        2020.0
# 5418  245487753     1397      101               47          134        2020.0
# 5419  111105497       12      100               47          110        2020.0
# 5420  461421559      228      149               47           56        2020.0
#
# [5421 rows x 15 columns]

# %%
#visualisazing correlation
sns.heatmap(df_numeric.corr(), annot=True)
plt.title('Correlation Matrix for all Features')
plt.gcf().set_size_inches(20, 10)

# %% [markdown]
# ### Feature Engineering

# %%
#getting profit for each movie
df['profit'] = df['gross'] - df['budget']
df.head()
# Out:
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
#
#      votes         director                   writer            star  \
# 0   927000  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    65000   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2  1200000   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3   221000     Jim Abrahams             Jim Abrahams     Robert Hays
# 4   108000     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#      budget      gross             company  runtime correct_country  \
# 0  19000000   46998772        Warner Bros.      146   United States
# 1   4500000   58853106   Columbia Pictures      104   United States
# 2  18000000  538375067           Lucasfilm      124   United States
# 3   3500000   83453539  Paramount Pictures       88   United States
# 4   6000000   39846344      Orion Pictures       98   United States
#
#   corect_date  correct_year     profit
# 0     June 13        1980.0   27998772
# 1      July 2        1980.0   54353106
# 2     June 20        1980.0  520375067
# 3      July 2        1980.0   79953539
# 4     July 25        1980.0   33846344

# %%
#checking column type
df['profit'].dtype
# Out:
# dtype('int64')

# %%
#getting a look at movies that are in loss
df.sort_values(by='profit').head(10)
# Out:
#                               name rating      genre  score   votes  \
# 5321                  The Irishman      R  Biography    7.8  344000
# 2130              The 13th Warrior      R     Action    6.6  119000
# 2733  The Adventures of Pluto Nash  PG-13     Action    3.8   25000
# 4213         Jin ling shi san chai      R      Drama    7.6   51000
# 1560              Cutthroat Island  PG-13     Action    5.7   27000
# 4975                 Live by Night      R     Action    6.4   54000
# 3022                     The Alamo  PG-13      Drama    6.0   20000
# 2349                     Supernova  PG-13     Horror    4.9   17000
# 5401                  Missing Link     PG  Animation    6.7   23000
# 3997               How Do You Know  PG-13     Comedy    5.4   48000
#
#               director                 writer               star     budget  \
# 5321   Martin Scorsese        Steven Zaillian     Robert De Niro  159000000
# 2130    John McTiernan       Michael Crichton   Antonio Banderas  160000000
# 2733     Ron Underwood          Neil Cuthbert       Eddie Murphy  100000000
# 4213       Yimou Zhang               Heng Liu     Christian Bale   94000000
# 1560      Renny Harlin  Michael Frost Beckner        Geena Davis   98000000
# 4975       Ben Affleck            Ben Affleck        Ben Affleck  108000000
# 3022  John Lee Hancock           Leslie Bohem       Dennis Quaid  107000000
# 2349       Walter Hill         William Malone       James Spader   90000000
# 5401      Chris Butler           Chris Butler       Hugh Jackman  100000000
# 3997   James L. Brooks        James L. Brooks  Reese Witherspoon  120000000
#
#          gross                     company  runtime correct_country  \
# 5321    968853         Tribeca Productions      209   United States
# 2130  61698899         Touchstone Pictures      102   United States
# 2733   7103973   Castle Rock Entertainment       95   United States
# 4213   2855644    Beijing New Picture Film      146           China
# 1560  10017322  Beckner/Gorman Productions      124   United States
# 4975  22678555                  Appian Way      129   United States
# 3022  25819961         Touchstone Pictures      137   United States
# 2349  14828081      Hammerhead Productions       90   United States
# 5401  26565710          Annapurna Pictures       93   United States
# 3997  48668907           Columbia Pictures      121   United States
#
#       corect_date  correct_year     profit
# 5321  November 27        2019.0 -158031147
# 2130    August 27        1999.0  -98301101
# 2733    August 16        2002.0  -92896027
# 4213  December 16        2011.0  -91144356
# 1560  December 22        1995.0  -87982678
# 4975   January 13        2017.0  -85321445
# 3022      April 9        2004.0  -81180039
# 2349   January 14        2000.0  -75171919
# 5401     April 12        2019.0  -73434290
# 3997  December 17        2010.0  -71331093

# %%
#checking how many movies are in loss
(df['profit'] < 0).sum()
# Out:
# 1744

# %%
#percentage of movies in loss
percentage_loss = (df['profit'] < 0).sum() *100 /len(df)
percentage_loss = pd.DataFrame({'percentage_loss': percentage_loss}, index=[0])
percentage_loss
# Out:
#    percentage_loss
# 0        32.171186

# %% [markdown]
# ### Data visualization

# %%
#number of movies produced per year
sns.histplot(x=df['correct_year'], label = 'Movies per 5 years', binwidth=5)
plt.legend()
plt.gcf().set_size_inches(12, 5)

# %%
#most popular genre by votes
ax = df[['genre','votes']].groupby(['genre']).sum().sort_values(by=['votes'], ascending=True)\
        .plot(kind='bar', alpha=0.8, title = 'Most Popular Movie Genres by Voting Numbers')

ax.set_xlabel('Genres')
ax.set_ylabel('Votes')

plt.gcf().set_size_inches(12, 5)

# %%
#most popular genre by gross
ax = df[['genre','gross']].groupby(['genre']).sum().sort_values(by=['gross'], ascending=True)\
        .plot(kind='bar', alpha=0.8, title = 'Most Popular Movie Genres by Gross')

ax.set_xlabel('Genres')
ax.set_ylabel('Gross')

plt.gcf().set_size_inches(12, 5)

# %% [markdown]
# ##### *Obsevation*
# - We see that the most popular genre by gross and votes is *action*.
# - And the least popular genre is *western*.

# %%
#casting rate of actors
stopword = STOPWORDS
wordcloud =  WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopword,
                min_font_size = 10).generate(' '.join(df['star']))

# plot the WordCloud image                      
plt.figure(figsize = (6, 6), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
#highest grossing actors and actoresses
ax = df[['star','gross']].groupby('star').sum().sort_values(by=['gross'], ascending=False).head(20)\
        .plot(kind='barh', title='Highest Grossing Actors & Actresses', alpha=0.8)
ax.set_ylabel('Actors & Actresses')
plt.gcf().set_size_inches(12,7)

# %%
#casting rate of directors
stopword = STOPWORDS
wordcloud =  WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopword,
                min_font_size = 10).generate(' '.join(df['director']))

# plot the WordCloud image                      
plt.figure(figsize = (6, 6), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
#Highest Grossing Directors
ax = df[['director','gross']].groupby('director').sum().sort_values(by=['gross'], ascending=False).head(20)\
        .plot(kind='barh', title='Highest Grossing Directors', alpha=0.8)
ax.set_ylabel('Directors')
plt.gcf().set_size_inches(12,7)

# %%
#countries that produce the highest no of movies
df['correct_country'].value_counts().head(10)
# Out:
# United States     5076
# United Kingdom      87
# France              41
# Germany             25
# Australia           14
# Spain               14
# Canada              13
# Japan               12
# South Korea         10
# Italy               10
# Name: correct_country, dtype: int64

# %%
#runtime of movies
df['runtime'].mean()
# Out:
# 108.15273934698395

# %%
df.to_csv('cleaned_movies')
